# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd

# %%
driver = webdriver.Chrome()
driver.get('http://widgets4.cre.ma/bodyluv.kr/products/reviews?product_code=52&iframe_id=crema-product-reviews-2&app=0&parent_url=http%3A%2F%2Fwww.bodyluv.kr%2Fproduct%2F%25EB%25A7%2588%25EC%2595%25BD%25EB%25A7%25A4%25ED%258A%25B8%25EB%25A6%25AC%25EC%258A%25A4%2F52%2Fcategory%2F25%2Fdisplay%2F1%2F&iframe=1')
#위젯을 get

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
soup #원하는 정보들이 한글로 표시되지 않음...어디에??
# Out:
# <!DOCTYPE html>
# <html class=" js flexbox canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers applicationcache svg inlinesvg smil svgclippaths placeholder cssfilters svgfilters" xmlns="http://www.w3.org/1999/xhtml"><head>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="authenticity_token" name="csrf-param"/>
# ...

# %%
url = "http://widgets4.cre.ma/bodyluv.kr/products/reviews?product_code=52&iframe_id=crema-product-reviews-2&app=0&parent_url=http%3A%2F%2Fwww.bodyluv.kr%2Fproduct%2F%25EB%25A7%2588%25EC%2595%25BD%25EB%25A7%25A4%25ED%258A%25B8%25EB%25A6%25AC%25EC%258A%25A4%2F52%2Fcategory%2F25%2Fdisplay%2F1%2F&iframe=1"
r = requests.get(url)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="UTF-8" />
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no" />
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="csrf-param" content="authenticity_token" />
# <meta name="csrf-token" content="ricSf7sXfqFewXfBEZaH3QMBalT3PHztrt5XHi8aVs6OUfuWWXkEvpEH/cayUgF01wdWj7OQTIOgQwk4/C0NgQ==" />
#     <title>상품 리뷰</title>
#     <!--[if lt IE 9]>
#       <script src="//assets4.cre.ma/m/widgets/javascripts/html5shiv-printshiv.js"></script>
#     <![endif]-->
#     <link rel="stylesheet" media="all" href="http://assets4.cre.ma/latte/assets/pc/application-4b2fb0ad9edac778ba65d69226911316.css" />
#     <style type="text/css">
#       span.star, span.camera, .sprite_comment {
# ...

# %%
def make_url(pageSize=10, page=1):
    return "http://m.stock.naver.com/api/json/sise/siseListJson.nhn?menu=market_sum&sosok=0&pageSize=" + str(pageSize) + "&page=" + str(page)

# %%
# driver = webdriver.Chrome()
# driver.get('http://www.bodyluv.kr/product/%EB%A7%88%EC%95%BD%EB%A7%A4%ED%8A%B8%EB%A6%AC%EC%8A%A4/52/category/25/display/1/?crema-product-reviews-2-page=2')

items = driver.find_element_by_css_selector('#contents > div.xans-element-.xans-product.xans-product-additional > div:nth-child(6)')
#items = reviews_selector.find_element_by_css_selector('#content > div > div.widget_reviews.js-pagination-list > div.widget_reviews__body.products_reviews_list__body > div')
#content > div > div.widget_reviews.js-pagination-list > div.widget_reviews__body.products_reviews_list__body > div > ul

# df = pd.DataFrame(columns=["id", "age", "comments"])


# for i in range(4):
#     id = items[i].find_elements_by_css_selector('li>##review_90874')[0].text
#     age = items[i].find_elements_by_css_selector('li>div>.review_option__content')[0].text
#     comments = items[i].find_elements_by_css_selector('li>div>.products_reviews_list_review__message_content')[0].text
    
#     data = {"id": id,
#             "age": age,
#             "comments": comments}
    
#     df.loc[len(df)] = data
        
#     driver.close

# df
