# %%
from selenium import webdriver
import bs4
import pandas as pd

# %%
driver = webdriver.Chrome()
driver.get('http://widgets4.cre.ma/bodyluv.kr/products/reviews?product_code=52&iframe_id=crema-product-reviews-2&app=0&parent_url=http%3A%2F%2Fwww.bodyluv.kr%2Fproduct%2F%25EB%25A7%2588%25EC%2595%25BD%25EB%25A7%25A4%25ED%258A%25B8%25EB%25A6%25AC%25EC%258A%25A4%2F52%2Fcategory%2F25%2Fdisplay%2F1%2F&iframe=1')

try:
    driver.find_element_by_css_selector(".js-link-expand").click()
except:
    print("no layer")

page = driver.find_element_by_css_selector('div>.page')
items = page.find_element_by_css_selector('ul>.reviews.reviews-product')




df = pd.DataFrame(columns=["id", "age", "comments"])
for i in range(6):
    
    
    id= items[i].find_elements_by_css_selector('li>')[0].text
    age = items[i].find_elements_by_css_selector('div>.review_option__content')[0].text
    comments = items[i].find_elements_by_css_selector('div>.products_reviews_list_review__message_content')[0].text

df
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-15-5a7b4d52fd30> in <module>()
#       8
#       9 page = driver.find_element_by_css_selector('div>.page')
# ---> 10 items = page.find_element_by_css_selector('ul>.reviews.reviews-product')
#      11
#      12
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in find_element_by_css_selector(self, css_selector)
#     428             element = element.find_element_by_css_selector('#foo')
#     429         """
# --> 430         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     431
#     432     def find_elements_by_css_selector(self, css_selector):
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in find_element(self, by, value)
#     651
#     652         return self._execute(Command.FIND_CHILD_ELEMENT,
# --> 653                              {"using": by, "value": value})['value']
#     654
#     655     def find_elements(self, by=By.ID, value=None):
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     626             params = {}
#     627         params['id'] = self._id
# --> 628         return self._parent.execute(command, params)
#     629
#     630     def find_element(self, by=By.ID, value=None):
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
# --> 312             self.error_handler.check_response(response)
#     313             response['value'] = self._unwrap_value(
#     314                 response.get('value', None))
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"ul>.reviews.reviews-product"}
#   (Session info: chrome=65.0.3325.181)
#   (Driver info: chromedriver=2.35.528157 (4429ca2590d6988c0745c24c8858745aaaec01ef),platform=Mac OS X 10.13.4 x86_64)

# %%
html = driver.page_source
soup = bs4.BeautifulSoup(html, 'lxml')

tmp = soup.find_all('tr', class = 'xans-record-')
li_list = tmp.find_all('li')

#for tmp in range(tmp[10],tmp[16]):
 #   df = pd.DataFrame(columns=["age", "comments"])
    
  #  for keyword in tmp:
    #    df.loc[len(df)] = {
     #       "rank":keyword.get_text("subject"),
   #         "comments":keyword.get_text(".xans-record-"),
      #  }
        
li_list
# Out:
#   File "<ipython-input-38-73645f2e905f>", line 1
#     tmp = soup.find_all('tr',class = 'xans-record-')
#                                  ^
# SyntaxError: invalid syntax

# %%
df = pd.DataFrame(columns=["age", "comments"])

for keyword in tmp:
        df.loc[len(df)] = {
            "rank":keyword.get_text("subject"),
            "comments":keyword.get_text(".xans-record-"),
        }
        
df
# Out:
#     age                                           comments
# 0   NaN  \n.xans-record-상품명.xans-record-\n             ...
# 1   NaN  \n.xans-record-소비자가.xans-record-\n            ...
# 2   NaN  \n.xans-record-판매가.xans-record-\n             ...
# 3   NaN  \n.xans-record-적립금.xans-record-\n             ...
# 4   NaN  \n.xans-record-국내·해외배송.xans-record-\n         ...
# 5   NaN  \n.xans-record-배송방법.xans-record-\n            ...
# 6   NaN  \n.xans-record-배송비.xans-record-\n             ...
# 7   NaN  마약매트리스.xans-record-\n.xans-record-- [필수] 옵션을 선...
# 8   NaN  겉커버.xans-record-\n.xans-record-- [선택] 옵션을 선택해 ...
# 9   NaN  방수속커버.xans-record-\n.xans-record-- [선택] 옵션을 선택...
# 10  NaN  \n.xans-record-6951.xans-record-\n            ...
# 11  NaN  \n.xans-record-6950.xans-record-\n            ...
# 12  NaN  \n.xans-record-6949.xans-record-\n            ...
# 13  NaN  \n.xans-record-6948.xans-record-\n            ...
# 14  NaN  \n.xans-record-6947.xans-record-\n            ...
# 15  NaN  \n.xans-record-2193.xans-record-\n            ...
# 16  NaN  \n.xans-record-2192.xans-record-\n            ...
# 17  NaN  \n.xans-record-2191.xans-record-\n            ...
# 18  NaN  \n.xans-record-2190.xans-record-\n            ...
# 19  NaN  \n.xans-record-2189.xans-record-\n            ...
